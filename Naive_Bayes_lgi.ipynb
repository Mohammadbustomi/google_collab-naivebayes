# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-05d0b86b-8e80-41a3-83c3-b3b18e09566c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05d0b86b-8e80-41a3-83c3-b3b18e09566c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

data = pd.read_excel('shooping_demo.xls')
data.head ()
# Out:
#        Day Discount Free Delivery  Buy
# 0  Weekday      Yes           Yes  Yes
# 1  Weekday      Yes           Yes  Yes
# 2  Weekend       No            No   No
# 3  Holiday      Yes           Yes  Yes
# 4  Weekday      Yes           Yes  Yes

# %%
data.shape
# Out:
# (50, 4)

# %%
data['Buy'].value_counts()
# Out:
# Buy
# Yes    41
# No      9
# Name: count, dtype: int64

# %%
PYes = 41/50
PNo = 9/50

# %%
print(PYes)
# Out:
# 0.82

# %%
print(PNo)
# Out:
# 0.18

# %%
pd.crosstab(data['Day'], data['Buy'])
# Out:
# Buy      No  Yes
# Day
# Holiday   6   18
# Weekday   2    9
# Weekend   1   14

# %%
PHolidayNo = 6/9
PWeekdayNo = 2/9
PWeekendNo = 1/9

PHolidayYes = 18/41
PWeekdayYes = 9/41
PWeekendYes = 14/41

PHoliday = 24/50
PWeekday = 11/50
PWeekend = 15/50

print(PWeekdayYes)
# Out:
# 0.21951219512195122

# %%
# P(A|B) ?
# P(B) = PWeekday
# P(A) = No Buy
# P(B|A) = P Weekday/NoBuy

# %%
PNoWeekday = (PWeekdayNo*PNo) / PWeekday
print(PNoWeekday)
# Out:
# 0.1818181818181818

# %%
PYesWeekday = (PWeekdayYes*PYes) / PWeekday
print(PYesWeekday)
# Out:
# 0.8181818181818181

# %%
# Probabilitas (Buy | Weekday) > dibanding dengan Probabilitas (NoBuy | Weekday)
print(PNoWeekday)
print(PYesWeekday)
# Out:
# 0.1818181818181818
# 0.8181818181818181

# %%
# Kondisi B dimana
# Day = Holiday
# Discount = Yes
# Free Delivery = Yes
# A = NoBuy
# P(A|B) = P(NoBuy | DiscountYes, Free Delivery Yes, PDayHoliday)

# %%
pd.crosstab(data['Discount'], data['Buy'])
# Out:
# Buy       No  Yes
# Discount
# No         5   12
# Yes        4   29

# %%
PNoDiscountNo = 5/9
PYesDiscountNo = 4/9

PNoDiscountYes = 12/41
PYesDiscountYes = 29/41

PNoDiscount = 17/50
PYesDiscount = 33/50

# %%
pd.crosstab(data['Free Delivery'], data['Buy'])
# Out:
# Buy            No  Yes
# Free Delivery
# No              4   10
# Yes             5   31

# %%
PNoDeliveryNo  = 4/9
PYesDeliveryNo = 5/9

PNoDeliveryYes  = 10/41
PYesDeliveryYes = 31/41

PNoDelivery  = 14/50
PYesDelivery = 36/50

# %%
# Kondisi B dimana
# Day = Holiday
# Discount = Yes
# Free Delivery = Yes
# P(A) = NoBuy = PNo
# P(B) = PYesDiscount, PYesDelivery, PHoliday
# P(B|A)1 = (PHoliday|No Buy) = PHolidayNo
# P(B|A)2 = (PYesDiscount|No Buy) = PYesDiscountNo
# P(B|A)3 = (PYesDelivery|No Buy) = PYesDeliveryNo
# P(B)1 = PHoliday
# P(B)2 = PYesDiscount
# P(B)3 = PYesDelivery

# ditanyakan P(A|B) ?
# Rumus
# P(A|B) = P(B|A)*P(A)/P(B)

# %%
PNoBuy1 = ((PHolidayNo*PYesDiscountNo*PYesDeliveryNo)*PNo)/(PHoliday*PYesDiscount*PYesDelivery)
print(PNoBuy1)
# Out:
# 0.12989982125784594

# %%
# Kondisi B dimana
# Day = Holiday
# Discount = Yes
# Free Delivery = Yes
# P(A) = Buy = PYes
# P(B) = PYesDiscount, PYesDelivery, PHoliday
# P(B|A)1 = (PHoliday|Buy) = PHolidayYes
# P(B|A)2 = (PYesDiscount|Buy) = PYesDiscountYes
# P(B|A)3 = (PYesDelivery|Buy) = PYesDeliveryYes
# P(B)1 = PHoliday
# P(B)2 = PYesDiscount
# P(B)3 = PYesDelivery

# ditanyakan P(A|B) ?
# Rumus
# P(A|B) = P(B|A)*P(A)/P(B)

# %%
PBuy2 = ((PHolidayYes*PYesDiscountYes*PYesDeliveryYes)*PYes)/(PHoliday*PYesDiscount*PYesDelivery)
print(PBuy2)
# Out:
# 0.8440667832398943

# %%
# probability of No purchase = 0.12989982125784594
# Probability of Purchase = 0.8440667832398943

# %%
PSum = PNoBuy1+PBuy2
print(PSum)
# Out:
# 0.9739666044977402

# %%
PBuy = (PBuy2/PSum)*100
print(PBuy)
# Out:
# 86.66280541263185

# %%
PNoBuy = (PNoBuy1/PSum)*100
print(PNoBuy)
# Out:
# 13.337194587368147

# %%
# P(Buy | Day=Weekday, FreeDelivery=Yes, Discount=Yes)

PBuy_a = ((PWeekdayYes * PYesDeliveryYes * PYesDiscountYes) * PYes) / (PWeekday * PYesDelivery * PYesDiscount)
PNoBuy_a = ((PWeekdayNo * PYesDeliveryNo * PYesDiscountNo) * PNo) / (PWeekday * PYesDelivery * PYesDiscount)

PSum_a = PBuy_a + PNoBuy_a

PBuy_a_final = (PBuy_a / PSum_a) * 100
PNoBuy_a_final = (PNoBuy_a / PSum_a) * 100

print("a. P(Buy | Weekday, Yes, Yes)     =", PBuy_a_final)
print("c. P(Not Buy | Weekday, Yes, Yes) =", PNoBuy_a_final)
# Out:
# a. P(Buy | Weekday, Yes, Yes)     = 90.69485518487818
# c. P(Not Buy | Weekday, Yes, Yes) = 9.30514481512183

# %%
# P(Buy | Day=Weekday, FreeDelivery=No, Discount=No)

PBuy_b = ((PWeekdayYes * PNoDeliveryYes * PNoDiscountYes) * PYes) / (PWeekday * PNoDelivery * PNoDiscount)
PNoBuy_b = ((PWeekdayNo * PNoDeliveryNo * PNoDiscountNo) * PNo) / (PWeekday * PNoDelivery * PNoDiscount)

PSum_b = PBuy_b + PNoBuy_b

PBuy_b_final = (PBuy_b / PSum_b) * 100
PNoBuy_b_final = (PNoBuy_b / PSum_b) * 100

print("b. P(Buy | Weekday, No, No)     =", PBuy_b_final)
print("d. P(Not Buy | Weekday, No, No) =", PNoBuy_b_final)
# Out:
# b. P(Buy | Weekday, No, No)     = 56.54084798345398
# d. P(Not Buy | Weekday, No, No) = 43.45915201654603

# %%
# P(Buy | Day=Weekend, FreeDelivery=Yes, Discount=Yes)

PBuy_e = ((PWeekendYes * PYesDeliveryYes * PYesDiscountYes) * PYes) / (PWeekend * PYesDelivery * PYesDiscount)
PNoBuy_e = ((PWeekendNo * PYesDeliveryNo * PYesDiscountNo) * PNo) / (PWeekend * PYesDelivery * PYesDiscount)

PSum_e = PBuy_e + PNoBuy_e

PBuy_e_final = (PBuy_e / PSum_e) * 100
PNoBuy_e_final = (PNoBuy_e / PSum_e) * 100

print("e. P(Buy | Weekend, Yes, Yes)     =", PBuy_e_final)
print("g. P(Not Buy | Weekend, Yes, Yes) =", PNoBuy_e_final)
# Out:
# e. P(Buy | Weekend, Yes, Yes)     = 96.80747821165603
# g. P(Not Buy | Weekend, Yes, Yes) = 3.1925217883439725

# %%
# P(Buy | Day=Weekend, FreeDelivery=No, Discount=No)

PBuy_f = ((PWeekendYes * PNoDeliveryYes * PNoDiscountYes) * PYes) / (PWeekend * PNoDelivery * PNoDiscount)
PNoBuy_f = ((PWeekendNo * PNoDeliveryNo * PNoDiscountNo) * PNo) / (PWeekend * PNoDelivery * PNoDiscount)

PSum_f = PBuy_f + PNoBuy_f

PBuy_f_final = (PBuy_f / PSum_f) * 100
PNoBuy_f_final = (PNoBuy_f / PSum_f) * 100

print("f. P(Buy | Weekend, No, No)     =", PBuy_f_final)
print("h. P(Not Buy | Weekend, No, No) =", PNoBuy_f_final)
# Out:
# f. P(Buy | Weekend, No, No)     = 80.18856806128463
# h. P(Not Buy | Weekend, No, No) = 19.811431938715383

# %%
import pandas as pd

hasil = {
    "Kasus": [
        "a. P(Buy | Weekday, Yes, Yes)",
        "b. P(Buy | Weekday, No, No)",
        "c. P(Not Buy | Weekday, Yes, Yes)",
        "d. P(Not Buy | Weekday, No, No)",
        "e. P(Buy | Weekend, Yes, Yes)",
        "f. P(Buy | Weekend, No, No)",
        "g. P(Not Buy | Weekend, Yes, Yes)",
        "h. P(Not Buy | Weekend, No, No)"
    ],
    "Probabilitas (%)": [
        90.69485518487818,
        56.54084798345398,
        9.30514481512183,
        43.45915201654603,
        96.80747821165603,
        80.18856806128463,
        3.1925217883439725,
        19.811431938715383
    ]
}

df = pd.DataFrame(hasil)
df
# Out:
#                                Kasus  Probabilitas (%)
# 0      a. P(Buy | Weekday, Yes, Yes)         90.694855
# 1        b. P(Buy | Weekday, No, No)         56.540848
# 2  c. P(Not Buy | Weekday, Yes, Yes)          9.305145
# 3    d. P(Not Buy | Weekday, No, No)         43.459152
# 4      e. P(Buy | Weekend, Yes, Yes)         96.807478
# 5        f. P(Buy | Weekend, No, No)         80.188568
# 6  g. P(Not Buy | Weekend, Yes, Yes)          3.192522
# 7    h. P(Not Buy | Weekend, No, No)         19.811432

# %% [markdown]
# Kesimpulan:
#
# Berdasarkan perhitungan Naive Bayes menggunakan dataset shopping_demo.xls, dapat disimpulkan bahwa:
#
# Peluang pembelian meningkat secara signifikan saat Discount = Yes dan Free Delivery = Yes, baik pada Weekday maupun Weekend.
#
# Faktor hari (Weekday/Weekend) tidak memberikan pengaruh besar terhadap keputusan pembelian dibandingkan faktor promosi.
#
# Faktor promosi (diskon dan gratis ongkir) merupakan variabel yang paling berpengaruh terhadap perilaku pelanggan dalam memutuskan untuk membeli.
#
# Dengan demikian, strategi promosi yang efektif untuk meningkatkan pembelian adalah dengan memberikan diskon dan layanan free delivery, terutama pada saat aktivitas pelanggan sedang tinggi, karena kombinasi keduanya terbukti meningkatkan kemungkinan pembelian hingga lebih dari 90%.
